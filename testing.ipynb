# %%
import numpy as np
import pandas as pd
from PIL import Image

# %%
radar = Image.open('Radar_Images/tiff/s_0025xx/s_00258001_tiff.tif')
np.array(radar).shape[1]
# Out:
# 1891

# %%
df = pd.read_csv("radar.csv")
df
# Out:
#        Unnamed: 0  long_start    long_end  lat_start    lat_end  center_long  \
# 0               1  230.676760  229.390720  64.239113  59.864001   230.033740
# 1               2  224.531750  222.273160  33.739494  16.946401   223.402455
# 2               3  204.730800  183.156570 -74.827200 -84.810770   193.943685
# 3               4  175.837720  171.496620 -76.866730 -80.226770   173.667170
# 4               5  327.585390  278.401460  83.964035  87.306125   302.993425
# ...           ...         ...         ...        ...        ...          ...
# 24033       24034  159.782810  150.944200  80.544693  71.817875   155.363505
# 24034       24035   71.376434   59.156655  74.838081  29.702621    65.266544
# 24035       24036  329.186250  326.477110 -32.683760 -49.650850   327.831680
# 24036       24037  278.998440  277.147240   1.943925 -12.887730   278.072840
# 24037       24038  251.013850  250.107670  -3.664608 -10.906130   250.560760
#
# ...

# %%
def radarWidth(tif_path):
    # Given a file path to a .tif file, return the number of columns of the raster
    print(tif_path)
    radar = Image.open(tif_path)
    radar_mat = np.array(radar)
    length = radar_mat.shape[1]
    return length

# %%
df["tif"].apply(radarWidth)
# Out:
# Radar_Images/tiff/s_0016xx/s_00168901_tiff.tif
# Radar_Images/tiff/s_0016xx/s_00168902_tiff.tif
# Radar_Images/tiff/s_0016xx/s_00169001_tiff.tif
# Radar_Images/tiff/s_0016xx/s_00169101_tiff.tif
# Radar_Images/tiff/s_0016xx/s_00169102_tiff.tif
# Radar_Images/tiff/s_0016xx/s_00169103_tiff.tif
# Radar_Images/tiff/s_0016xx/s_00169201_tiff.tif
# Radar_Images/tiff/s_0016xx/s_00169301_tiff.tif
# Radar_Images/tiff/s_0016xx/s_00169302_tiff.tif
# Radar_Images/tiff/s_0016xx/s_00169401_tiff.tif
# Radar_Images/tiff/s_0016xx/s_00169501_tiff.tif
# Radar_Images/tiff/s_0016xx/s_00169502_tiff.tif
# Radar_Images/tiff/s_0016xx/s_00169601_tiff.tif
# Radar_Images/tiff/s_0016xx/s_00169701_tiff.tif
# Radar_Images/tiff/s_0016xx/s_00169801_tiff.tif
# Radar_Images/tiff/s_0016xx/s_00169802_tiff.tif
# Radar_Images/tiff/s_0016xx/s_00169901_tiff.tif
# Radar_Images/tiff/s_0017xx/s_00170101_tiff.tif
# Radar_Images/tiff/s_0017xx/s_00170201_tiff.tif
# Radar_Images/tiff/s_0017xx/s_00170202_tiff.tif
# ...
